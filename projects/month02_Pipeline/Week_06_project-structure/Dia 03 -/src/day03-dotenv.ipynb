# %%
import os
from dotenv import load_dotenv
from pathlib import Path
from pipeline import run
from logger import log

# %%
load_dotenv()
# Out:
# True

# %%
log("config", f"ENV={os.getenv('ENV')}")
log("config", f"LOG_LEVEL={os.getenv('LOG_LEVEL')}")
log("config", f"BASE_DIR={os.getenv('BASE_DIR')}")
log("config", f"SAMPLE_SIZE={os.getenv('SAMPLE_SIZE')}")
# Out:
# [18:11:03] [INFO] [config] ENV=development
# [18:11:03] [INFO] [config] LOG_LEVEL=INFO
# [18:11:03] [INFO] [config] BASE_DIR=C:/Users/Ceifas/OneDrive/Desktop/data-engineering-portfolio/projects/month02_Pipeline
# [18:11:03] [INFO] [config] SAMPLE_SIZE=50000

# %%
if __name__ == "__main__":
    run()
# Out:
# [18:11:25] [INFO] [pipeline] iniciando — 2026-04-29 18:11:25
# [warning] Arquivo não encontrado: raw\deliveries.csv
# [warning] Arquivo não encontrado: raw\drivers.csv
# [warning] Arquivo não encontrado: raw\hubs.csv
# [18:11:25] [INFO] [pipeline] tempo total: 0.00s
# [18:11:25] [INFO] [error] 'deliveries'
# Traceback (most recent call last):
#   File "c:\Users\Ceifas\OneDrive\Desktop\data-engineering-portfolio\projects\month02_Pipeline\Week_06_project-structure\Dia 03 -\src\pipeline.py", line 61, in run
#     dfs = _extract(str(config.RAW_PATH))
#           ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Ceifas\OneDrive\Desktop\data-engineering-portfolio\projects\month02_Pipeline\Week_06_project-structure\Dia 03 -\src\pipeline.py", line 17, in _extract
#     check_duplicates(dfs["deliveries"], "delivery_id", "deliveries")
#                      ~~~^^^^^^^^^^^^^^
# KeyError: 'deliveries'
