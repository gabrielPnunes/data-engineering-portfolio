# %% [markdown]
# ## Leituras e Escrita de textos

# %%
#Leitura
caminho = r"C:\Users\AMD\Desktop\projects\01_python_fundamentals\data\texto_aleatorio.txt"

with open(caminho, "r", encoding="utf-8") as arquivo:
    conteudo = arquivo.read()


#Escrita
caminho = r"C:\Users\AMD\Desktop\projects\01_python_fundamentals\data\texto_aleatorio.txt"

with open(caminho, "a", encoding="utf-8") as arquivo:
    arquivo.write("Seus vícios engolirão qualquer quantidade de tempo.")

# %% [markdown]
# ## Leitura e Escritas de JSONS

# %%
import json

with open("dados.json", "r") as f:
    dados = json.load(f)


with open("dados.json", "w") as f:
    json.dump(dados, f, indent=4)

# %%
import csv

with open("dados.csv") as f:
    reader = csv.reader(f)
    for linha in reader:
        print(linha)


with open("dados.csv") as f:
    reader = csv.DictReader(f)
    for linha in reader:
        print(linha["nome"])
